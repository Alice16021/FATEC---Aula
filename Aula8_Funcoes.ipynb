# %% [markdown]
# <a href="https://colab.research.google.com/github/Alice16021/FATEC---Aula/blob/main/Aula8_Funcoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Funções em Python

# %% [markdown]
# ### 🎯 Objetivos da Aula:
# - Compreender o conceito de função em Python.
# - Aprender a declarar, chamar e utilizar funções.
# - Trabalhar com parâmetros, retorno e reutilização de código.
# - Praticar com exemplos aplicados e desafios.

# %% [markdown]
# ## 📌 1. O que é uma Função?

# %% [markdown]
# Uma função é um **bloco de código reutilizável** que executa uma tarefa específica. Em vez de escrever o mesmo código várias vezes, colocamos esse código dentro de uma função e chamamos essa função quando necessário.

# %% [markdown]
# ## 🧱 2. Estrutura Básica

# %%
def nome_da_funcao(parâmetros):
    # bloco de código
    return resultado

# %% [markdown]
# ## 🧪 3. Funções Sem Parâmetros e Sem Retorno

# %%
def exibir_mensagem():
    print("Olá! Esta é uma função sem parâmetros e sem retorno.")

exibir_mensagem()

# %% [markdown]
# ## ✉️ 4. Funções com Parâmetros

# %%
def saudacao(nome):
    print(f"Olá, {nome}! Seja bem-vindo.")

saudacao("Carlos")
saudacao("Marina")
# Out:
# Olá, Carlos! Seja bem-vindo.
# Olá, Marina! Seja bem-vindo.

# %% [markdown]
# ## 🔁 5. Funções com Retorno

# %%
def somar(a, b):
    return a + b

resultado = somar(5, 3)
print(f"A soma é: {resultado}")
# Out:
# A soma é: 8

# %% [markdown]
# ## ❓ 6. Diferença entre `print` e `return`

# %%
def exemplo_print(x):
    print(x * 2)

def exemplo_return(x):
    return x * 2

exemplo_print(5)
resultado = exemplo_return(5)
print(resultado)

# %% [markdown]
# ## 📚 7. Exemplos Aplicados

# %%
def eh_par(numero):
    return numero % 2 == 0

print(eh_par(4))
print(eh_par(7))

# %%
def fatorial(n):
    resultado = 1
    for i in range(2, n + 1):
        resultado *= i
    return resultado

print(fatorial(5))

# %%
def calcular_media(n1, n2):
    return (n1 + n2) / 2

print(calcular_media(7, 9))

# %% [markdown]
# ## 🧠 8. Exercícios Propostos

# %% [markdown]
# 1. Crie uma função que receba o nome de um aluno e exiba uma mensagem de boas-vindas.
# 2. Crie uma função que receba dois números e retorne a média entre eles.
# 3. Crie uma função que receba uma lista de números e retorne quantos são pares.
# 4. Crie uma função chamada `eh_primo(numero)` que retorne `True` se o número for primo.
# 5. Crie uma função `converter_para_fahrenheit(celsius)` que converta graus Celsius para Fahrenheit.
# 6. Crie uma função `valida_idade(idade)` que retorne se a pessoa é maior de idade.
# 7. Crie uma função `exibe_menu()` que imprima um menu simples na tela.
# 8. Crie uma função `calcular_desconto(valor, percentual=10)` que aplique um desconto percentual ao valor.
# 9. Crie uma função que conte o número de vogais em uma palavra.
# 10. Crie um menu com funções para:
#     - Cadastrar nomes
#     - Listar nomes
#     - Sair do programa

# %%
def Olá ():
  print("Oie")
  Olá()

# %%
#soma
def soma (x,y):
  return x+y
print (soma(2,3))
# Out:
# 5

# %%
num1= int(input("Digite um número: "))
num2= int(input("Digite outro número: "))
def soma (num1,num2):
  print (soma)
# Out:
# Digite um número: 1
# Digite outro número: 8

# %% [markdown]
# ## 🧪 11. Desafio Final (Avançado)

# %% [markdown]
# > Simule um sistema de cadastro de produtos com as seguintes opções:
# ```
# 1 - Cadastrar produto
# 2 - Listar produtos
# 3 - Buscar produto pelo nome
# 4 - Sair
# ```
# - Use uma lista para armazenar os produtos.
# - Crie funções para cada opção.
# - Utilize laços de repetição e estruturas de decisão junto com funções.

# %%
def cadastrar_produto(produtos):
    nome = input("Digite o nome do produto: ")
    preco = int(input("Digite o preço do produto: "))
    produto = {"nome": nome, "preco": preco}
    produtos.append(produto)
    print("Produto cadastrado com sucesso!")
def listar_produtos(produtos):
    if not produtos:
        print("Nenhum produto cadastrado.")
    else:
        print("Lista de Produtos:")
        for i, produto in enumerate(produtos, start=1):
            print(f"{i}. Nome: {produto['nome']}, Preço: R${produto['preco']:.2f}")
def buscar_produto(produtos):
    nome = input("Digite o nome do produto a ser buscado: ")
    for produto in produtos:
        if produto["nome"] == nome:
            print(f"Produto encontrado: Nome: {produto['nome']}, Preço: R${produto['preco']:.2f}")
            return
    print("Produto não encontrado.")
def main():
    produtos = []
    while True:
        print("\nMenu:")
        print("1 - Cadastrar produto")
        print("2 - Listar produtos")
        print("3 - Buscar produto pelo nome")
        print("4 - Sair")
        opcao = input("Escolha uma opção: ")
        if opcao == "1":
            cadastrar_produto(produtos)
        elif opcao == "2":
            listar_produtos(produtos)
        elif opcao == "3":
            buscar_produto(produtos)
        elif opcao == "4":
            print("Saindo do programa. Até logo!")
            break
        else:
            print("Opção inválida. Tente novamente.")
if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1 - Cadastrar produto
# 2 - Listar produtos
# 3 - Buscar produto pelo nome
# 4 - Sair
# Escolha uma opção: 2
# Nenhum produto cadastrado.
#
# Menu:
# 1 - Cadastrar produto
# 2 - Listar produtos
# 3 - Buscar produto pelo nome
# 4 - Sair
# Escolha uma opção: 3
# Digite o nome do produto a ser buscado: Alcool
# Produto não encontrado.
#
# Menu:
# 1 - Cadastrar produto
# 2 - Listar produtos
# 3 - Buscar produto pelo nome
# 4 - Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1234/3087051653.py in <cell line: 0>()
#      40             print("Opção inválida. Tente novamente.")
#      41 if __name__ == "__main__":
# ---> 42     main()
#
# /tmp/ipykernel_1234/3087051653.py in main()
#      27         print("3 - Buscar produto pelo nome")
#      28         print("4 - Sair")
# ---> 29         opcao = input("Escolha uma opção: ")
# ...

# %% [markdown]
# ## ✅ Conclusão

# %% [markdown]
# - Funções ajudam a organizar, dividir e reutilizar código.
# - É essencial dominar funções para criar sistemas reais.
# - Funções facilitam testes, manutenção e clareza do código.

# %%
def ola():
  print("Olá Mundo")
ola()
# Out:
# Olá Mundo

# %%
def saudacao(nome):
  print (f"Ola {nome}")

nome= input("Digite seu nome: ")
saudacao(nome)
# Out:
# Digite seu nome: Alice
# Ola Alice

# %%
def soma(num1,num2):
  return num1+num2

num1=int(input("Digite um número: "))
num2=int(input("Digite outro número: "))
soma(num1,num2)
# Out:
# Digite um número: 10
# Digite outro número: 30
# 40
